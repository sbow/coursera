# %% [markdown]
# ### Gradient Descent  - Python
# #### Week 1 octave univariate regression - implementation
# ##### Shaun Bowman
# ##### Sun Apr 8 2018

# %%
# Do inports ect
import matplotlib
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline  

import math
import random
import numpy as np

# %%
# Setup input signals
n_points = 100
y_gain = 2.
y_offset = 15.
random_strength = 10

x = [random.random()-0.5+i for i in range(n_points)]
y = [i*y_gain*(random.random()+0.5) + y_offset*random.random() + random.random()*random_strength for i in x]

# %% [markdown]
# $
# J(\theta1) = \frac{1/2m}
# $

# %%
# Do regression

# %%
# Plotting
plt.plot(x,y)
plt.show()
